# %% [raw]
# Clustering is unsupervidsed ml algorithm using to group similar data points into clusters based upon their characteristics, features and similarities.

# %% [raw]
# clustering is of 4 types:
# 1- Partioning(k-means, k- medoids)
# 2- hierarachial(agg,div)
# 3- density based(DBSCAN)
# 4- Grid(sting,CLIQUE)
# 5- Model(GMM)
# 6- Fuzzy(fuzzy c-means)

# %% [raw]
# PARTIONING CLUSTERING:
# It divides the data into fixed no. of clusters
# A) K-MEANS- In k-means one data point should belong to 1 cluster.
#            the data point will be assigned to that least distance cluster.
# Algorithms:
# 1- Assume no. of clusters(k)
# 2- Assign the cnetroid to the cluster
# 3- Calculate the distance between clusters and dp
# EUCLIDIAN DISTANCE = formula
# 4- Based on the distance assign the dp to the nearest cluster
# 5- After assigning dp to the cluster update the centroid value
#     x1+x2/2 , y1+y2/2 --> C+O/2 , C+O/2
# 6- Repeat the steps until each and every dp assigned to clusters.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
data ={
    "Annual_income": [ 15,16,17,18,19,20,22,25,27,30,
                       60,62,65,67,70,72,75,77,80,82],
    "Spending_score": [39,81,6,77,40,76,94,3,72,14,
                       55,52,59,61,58,60,63,65,62,64]
}
df = pd.DataFrame(data)
print(df.head())
# Out:
#    Annual_income  Spending_score
# 0             15              39
# 1             16              81
# 2             17               6
# 3             18              77
# 4             19              40

# %%
plt.figure(figsize=(4,3))
plt.scatter(df["Annual_income"],
            df["Spending_score"],
            color='blue')
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
# Out:
# Text(0, 0.5, 'Spending Score')

# %%
scaler = StandardScaler()
X = scaler.fit_transform(df)

# %%
#Apply the Elbow Method
wcss = []
for i in range(1,11):

    kmeans = KMeans(
        n_clusters=i,
        random_state=42,
        n_init=10
    )

    kmeans.fit(X)

    wcss.append(kmeans.inertia_)

plt.figure(figsize=(7,5))
plt.plot(range(1,11), wcss, marker='o')

plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.title("Elbow Method")

plt.show()

# %%
# Select features
X = df[["Annual_income", "Spending_score"]]

# Apply StandardScaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled = scaler.fit_transform(X)

# Display the scaled data
scaled_df = pd.DataFrame(
    x_scaled,
    columns=["Annual_income", "Spending_score"]
)

scaled_df.head()
# Out:
#    Annual_income  Spending_score
# 0      -1.200869       -0.682301
# 1      -1.162069        1.103160
# 2      -1.123269       -2.085163
# 3      -1.084468        0.933116
# 4      -1.045668       -0.639790

# %% [raw]
# K- Medoids
# All same points similar to K-means
# except to euclidian ..it goes manhattan distance
# mod x2-x1 + mod y2-y1
